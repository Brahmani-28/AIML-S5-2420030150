# %% [markdown]
# #My First Program

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# Python Variables and Data Types

# %%
x=5
y="john"
z='c'
print(z)
print(y)
print(x)
# Out:
# c
# john
# 5

# %%
x = str(3)
y = int(3)
z = float(3)
print(x,y,z)
# Out:
# 3 3 3.0

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = "John"
# is the same as
x = 'John'
# x=2
print(x)
# Out:
# John

# %%
a = 4
a = 5
A = "Sally"
print(a, A)
# Out:
# 5 Sally

# %%
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"
print(myvar,my_var,_my_var,myVar,MYVAR,myvar2 )
# Out:
# John John John John John John

# %%
#Multiple Assignment
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# ------Python Collections (List/Tuple/Set/Disctionary)------

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(fruits)
# Out:
# apple
# banana
# ['apple', 'banana', 'cherry']

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)

# %%
thistuple1 = ("apple", "banana", "cherry", "apple", "cherry", 3, 5, 6, 'grapes')
print(thistuple1)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry', 3, 5, 6, 'grapes')

# %%
thisset = {"banana", "apple", "cherry", False, 1, 2}
print(thisset)
# Out:
# {False, 'apple', 2, 1, 'cherry', 'banana'}

# %%
thisdict = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}
thisdict = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = 5
y = "John"
print(x,y)
# Out:
# 5 John

# %%
import sys
print(sys.version)
# Out:
# 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]

# %% [markdown]
# ------Python Loops------

# %%
if 5 > 2:
    print("Five is greater than two!")

if 5 > 1:
    print("Five is greater than one!")
# Out:
# Five is greater than two!
# Five is greater than one!

# %%
a = 33
b = 33

if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 200
b = 33
if b > a:
     print("b is greater than a")
elif a == b:
     print("a and b are equal")
else:
     print("a is greater than b")
# Out:
# a is greater than b

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x)
# Out:
# apple
# banana
# cherry

# %%
for x in range(7):
    print(3)
else:
    print("Finally finished!")
# Out:
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# Finally finished!

# %% [markdown]
# -------Python Functions---------

# %%
x = "awesome"
def myfunc():
    print("Python is " + x)
myfunc()
# Out:
# Python is awesome

# %%
x = "awesome"
def myfunc():
  x = "fantastic"
print("Python is " + x)
myfunc()
print("Python is " + x)
# Out:
# Python is awesome
# Python is awesome
